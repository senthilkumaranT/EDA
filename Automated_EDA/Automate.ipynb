# %%
# %pip install ydata-profiling seaborn

# %%
# %pip install numpy
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# !pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-3.18.2-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: lz4 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (4.4.4)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (4.13.4)
# Requirement already satisfied: certifi in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (2025.4.26)
# Requirement already satisfied: cycler in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (0.12.1)
# Collecting dash<=2.18.2 (from dtale)
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting dash-bootstrap-components<=1.7.1 (from dtale)
#   Downloading dash_bootstrap_components-1.7.1-py3-none-any.whl.metadata (17 kB)
# Collecting dash_daq<=0.5.0 (from dtale)
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ---------------------------------------- 642.7/642.7 kB 12.3 MB/s  0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: et_xmlfile in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (2.0.0)
# Requirement already satisfied: Flask in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (3.1.0)
# Collecting Flask-Compress (from dtale)
#   Downloading flask_compress-1.18-py3-none-any.whl.metadata (9.2 kB)
# Collecting future>=0.14.0 (from dtale)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: itsdangerous in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (2.2.0)
# Collecting kaleido (from dtale)
#   Downloading kaleido-1.1.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (3.10.0)
# Requirement already satisfied: missingno in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (0.5.2)
# Requirement already satisfied: networkx in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (3.4.2)
# Requirement already satisfied: numpy in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (2.1.3)
# Requirement already satisfied: openpyxl!=3.2.0b1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (3.1.5)
# Requirement already satisfied: packaging in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (24.2)
# Requirement already satisfied: pandas in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (2.2.3)
# Collecting pkginfo (from dtale)
#   Downloading pkginfo-1.12.1.2-py3-none-any.whl.metadata (13 kB)
# Collecting plotly (from dtale)
#   Downloading plotly-6.3.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (2.32.4)
# Requirement already satisfied: scikit-learn in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (1.6.1)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2,<1.16.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (1.13.1)
# Requirement already satisfied: seaborn in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (0.13.2)
# Collecting squarify (from dtale)
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Requirement already satisfied: statsmodels in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (0.14.5)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (1.17.0)
# Requirement already satisfied: werkzeug in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dtale) (3.1.3)
# Collecting xarray (from dtale)
#   Downloading xarray-2025.9.1-py3-none-any.whl.metadata (12 kB)
# Collecting xlrd (from dtale)
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting Flask (from dtale)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting werkzeug (from dtale)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting dash-html-components==2.0.0 (from dash<=2.18.2->dtale)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash<=2.18.2->dtale)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash<=2.18.2->dtale)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dash<=2.18.2->dtale) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dash<=2.18.2->dtale) (4.14.1)
# Collecting retrying (from dash<=2.18.2->dtale)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in c:\users\karis\appdata\roaming\python\python312\site-packages (from dash<=2.18.2->dtale) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from dash<=2.18.2->dtale) (80.3.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from Flask->dtale) (3.1.6)
# Requirement already satisfied: click>=8.1.3 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from Flask->dtale) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from Flask->dtale) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from werkzeug->dtale) (2.1.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.7)
# Requirement already satisfied: colorama in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from click>=8.1.3->Flask->dtale) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from plotly->dtale) (1.41.1)
# Requirement already satisfied: brotli in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from Flask-Compress->dtale) (1.1.0)
# Collecting pyzstd (from Flask-Compress->dtale)
#   Downloading pyzstd-0.17.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: zipp>=3.20 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata->dash<=2.18.2->dtale) (3.21.0)
# Collecting choreographer>=1.0.10 (from kaleido->dtale)
#   Downloading choreographer-1.1.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting logistro>=1.0.8 (from kaleido->dtale)
#   Downloading logistro-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from kaleido->dtale) (3.10.18)
# Collecting pytest-timeout>=2.4.0 (from kaleido->dtale)
#   Downloading pytest_timeout-2.4.0-py3-none-any.whl.metadata (20 kB)
# Collecting simplejson>=3.19.3 (from choreographer>=1.0.10->kaleido->dtale)
#   Downloading simplejson-3.20.2-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from pytest-timeout>=2.4.0->kaleido->dtale) (8.4.0)
# Requirement already satisfied: iniconfig>=1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido->dtale) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido->dtale) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido->dtale) (2.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtale) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtale) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtale) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtale) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtale) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from pandas->dtale) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from requests->dtale) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from requests->dtale) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from requests->dtale) (2.4.0)
# Collecting joblib>=1.2.0 (from scikit-learn->dtale)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->dtale) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->dtale) (1.0.1)
# Downloading dtale-3.18.2-py2.py3-none-any.whl (17.6 MB)
#    ---------------------------------------- 0.0/17.6 MB ? eta -:--:--
#    ------- -------------------------------- 3.1/17.6 MB 15.3 MB/s eta 0:00:01
#    ------------- -------------------------- 6.0/17.6 MB 14.7 MB/s eta 0:00:01
#    -------------------- ------------------- 8.9/17.6 MB 14.6 MB/s eta 0:00:01
#    -------------------------- ------------- 11.8/17.6 MB 14.5 MB/s eta 0:00:01
#    --------------------------------- ------ 14.7/17.6 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------  17.6/17.6 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 17.6/17.6 MB 13.1 MB/s  0:00:01
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------- ----------------------- 3.1/7.8 MB 15.3 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/7.8 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 14.2 MB/s  0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading dash_bootstrap_components-1.7.1-py3-none-any.whl (229 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading plotly-6.3.0-py3-none-any.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------------ --------------------------- 3.1/9.8 MB 15.3 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.8 MB 14.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 11.3 MB/s  0:00:00
# Downloading flask_compress-1.18-py3-none-any.whl (9.3 kB)
# Downloading kaleido-1.1.0-py3-none-any.whl (66 kB)
# Downloading choreographer-1.1.1-py3-none-any.whl (52 kB)
# Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Downloading pytest_timeout-2.4.0-py3-none-any.whl (14 kB)
# Downloading simplejson-3.20.2-cp312-cp312-win_amd64.whl (75 kB)
# Downloading pkginfo-1.12.1.2-py3-none-any.whl (32 kB)
# Downloading pyzstd-0.17.0-cp312-cp312-win_amd64.whl (246 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Downloading xarray-2025.9.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 17.8 MB/s  0:00:00
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Building wheels for collected packages: dash_daq
#   Building wheel for dash_daq (setup.py): started
#   Building wheel for dash_daq (setup.py): finished with status 'done'
#   Created wheel for dash_daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669799 sha256=071af1072d1dfc54f792fda79e1cda21d34e8ddf7529971c8d24729323fb815e
#   Stored in directory: c:\users\karis\appdata\local\pip\cache\wheels\40\89\1a\4435006b003f97da22dbcad819d26f957dad9d54a1678876fd
# Successfully built dash_daq
# Installing collected packages: strsimpy, squarify, dash-table, dash-html-components, dash-core-components, xlrd, werkzeug, simplejson, retrying, pyzstd, plotly, pkginfo, logistro, joblib, future, pytest-timeout, Flask, choreographer, xarray, kaleido, Flask-Compress, dash, dash_daq, dash-bootstrap-components, dtale
#
#    ----------------------------------------  0/25 [strsimpy]
#    ----------------------------------------  0/25 [strsimpy]
#    --- ------------------------------------  2/25 [dash-table]
#    -------- -------------------------------  5/25 [xlrd]
#   Attempting uninstall: werkzeug
#    -------- -------------------------------  5/25 [xlrd]
#    --------- ------------------------------  6/25 [werkzeug]
#     Found existing installation: Werkzeug 3.1.3
#    --------- ------------------------------  6/25 [werkzeug]
#     Uninstalling Werkzeug-3.1.3:
#    --------- ------------------------------  6/25 [werkzeug]
#       Successfully uninstalled Werkzeug-3.1.3
#    --------- ------------------------------  6/25 [werkzeug]
#    --------- ------------------------------  6/25 [werkzeug]
#    --------- ------------------------------  6/25 [werkzeug]
#    --------- ------------------------------  6/25 [werkzeug]
#    --------- ------------------------------  6/25 [werkzeug]
#    --------- ------------------------------  6/25 [werkzeug]
#    ----------- ----------------------------  7/25 [simplejson]
#    ----------- ----------------------------  7/25 [simplejson]
#    ----------- ----------------------------  7/25 [simplejson]
#    -------------- -------------------------  9/25 [pyzstd]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ---------------- ----------------------- 10/25 [plotly]
#    ----------------- ---------------------- 11/25 [pkginfo]
#    ----------------- ---------------------- 11/25 [pkginfo]
#   Attempting uninstall: joblib
#    ----------------- ---------------------- 11/25 [pkginfo]
#     Found existing installation: joblib 1.1.1
#    ----------------- ---------------------- 11/25 [pkginfo]
#    -------------------- ------------------- 13/25 [joblib]
#     Uninstalling joblib-1.1.1:
#    -------------------- ------------------- 13/25 [joblib]
#       Successfully uninstalled joblib-1.1.1
#    -------------------- ------------------- 13/25 [joblib]
#    -------------------- ------------------- 13/25 [joblib]
#    -------------------- ------------------- 13/25 [joblib]
#    -------------------- ------------------- 13/25 [joblib]
#    -------------------- ------------------- 13/25 [joblib]
#    -------------------- ------------------- 13/25 [joblib]
#    -------------------- ------------------- 13/25 [joblib]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ---------------------- ----------------- 14/25 [future]
#    ------------------------ --------------- 15/25 [pytest-timeout]
#   Attempting uninstall: Flask
#    ------------------------ --------------- 15/25 [pytest-timeout]
#     Found existing installation: Flask 3.1.0
#    ------------------------ --------------- 15/25 [pytest-timeout]
#     Uninstalling Flask-3.1.0:
#    ------------------------ --------------- 15/25 [pytest-timeout]
#       Successfully uninstalled Flask-3.1.0
#    ------------------------ --------------- 15/25 [pytest-timeout]
#    ------------------------- -------------- 16/25 [Flask]
#    ------------------------- -------------- 16/25 [Flask]
#    --------------------------- ------------ 17/25 [choreographer]
#    --------------------------- ------------ 17/25 [choreographer]
#    --------------------------- ------------ 17/25 [choreographer]
#    --------------------------- ------------ 17/25 [choreographer]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ---------------------------- ----------- 18/25 [xarray]
#    ------------------------------ --------- 19/25 [kaleido]
#    ------------------------------ --------- 19/25 [kaleido]
#    ------------------------------ --------- 19/25 [kaleido]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    --------------------------------- ------ 21/25 [dash]
#    ----------------------------------- ---- 22/25 [dash_daq]
#    ------------------------------------ --- 23/25 [dash-bootstrap-components]
#    ------------------------------------ --- 23/25 [dash-bootstrap-components]
#    ------------------------------------ --- 23/25 [dash-bootstrap-components]
#    ------------------------------------ --- 23/25 [dash-bootstrap-components]
#    ------------------------------------ --- 23/25 [dash-bootstrap-components]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    -------------------------------------- - 24/25 [dtale]
#    ---------------------------------------- 25/25 [dtale]
#
# Successfully installed Flask-3.0.3 Flask-Compress-1.18 choreographer-1.1.1 dash-2.18.2 dash-bootstrap-components-1.7.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 dash_daq-0.5.0 dtale-3.18.2 future-1.0.0 joblib-1.5.2 kaleido-1.1.0 logistro-1.1.0 pkginfo-1.12.1.2 plotly-6.3.0 pytest-timeout-2.4.0 pyzstd-0.17.0 retrying-1.4.2 simplejson-3.20.2 squarify-0.4.4 strsimpy-0.2.1 werkzeug-3.0.6 xarray-2025.9.1 xlrd-2.0.2
#   DEPRECATION: Building 'dash_daq' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'dash_daq'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.5.2 which is incompatible.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://sk:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# c:\Users\karis\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtale\pandas_util.py:21: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\karis\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtale\pandas_util.py:21: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\karis\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtale\pandas_util.py:21: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\karis\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtale\pandas_util.py:21: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# c:\Users\karis\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtale\pandas_util.py:21: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
# %pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (2.2.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (2.1.3)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (3.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (4.67.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (1.13.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (3.1.6)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (6.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.17.0)
# Requirement already satisfied: colorama in c:\users\karis\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv

# Workaround for Sweetviz bug with numpy.VisibleDeprecationWarning on numpy >=1.24
import warnings
import numpy as np

if not hasattr(np, "VisibleDeprecationWarning"):
    import types
    np.VisibleDeprecationWarning = type(
        "VisibleDeprecationWarning", (Warning,), {}
    )

report = sv.analyze(df)
report.show_html('sweetviz_report.html')
# Out:
# Feature: total_bill                          |█▎        | [ 12%]   01:45 -> (12:20 left)
# Feature: total_bill                          |█▎        | [ 12%]   01:29 -> (10:23 left)
# Feature: total_bill                          |█▎        | [ 12%]   01:12 -> (08:27 left)
# Feature: total_bill                          |█▎        | [ 12%]   00:48 -> (05:38 left)
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
